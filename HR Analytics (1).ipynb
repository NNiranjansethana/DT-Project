# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/IBM_HR_Attrition_Rate_Analytics/9ec6236290b60a0cbf510d7ada30d84888635692/ibm-hr-analytics-employee-attrition-performance.zip")
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# Observation
#
# 1. DistanceFromHome has huge gap between 75% and max.
# 2.YearsAtCompany has huge gap between 75% and max.
# 3.YearsInCurrentRole has also huge gapbetween 75% and max.
# 4. YearsScinceLastPromotion has also huge gap between 75% and max.
# 5. YearsWithCurrManager has also huge gap between75% and max.

# %%
data['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
data['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
data['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
data['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
data['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
data['MaritalStatus'].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
data['Over18'].value_counts()
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %%
data['OverTime'].value_counts()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enco=LabelEncoder()

# %%
df=lab_enco.fit_transform(data['Attrition'])
data['Attrition']=df
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df=lab_enco.fit_transform(data['BusinessTravel'])
data['BusinessTravel']=df

# %%
df=lab_enco.fit_transform(data['Department'])
data['Department']=df
df=lab_enco.fit_transform(data['EducationField'])
data['EducationField']=df
df=lab_enco.fit_transform(data['Gender'])
data['Gender']=df

# %%
df=lab_enco.fit_transform(data['JobRole'])
data['JobRole']=df
df=lab_enco.fit_transform(data['MaritalStatus'])
data['MaritalStatus']=df
df=lab_enco.fit_transform(data['OverTime'])
data['OverTime']=df
df=lab_enco.fit_transform(data['Over18'])
data['Over18']=df

# %%
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int32
#  2   BusinessTravel            1470 non-null   int32
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int32
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int32
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   int32
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df_corr=data.corr().abs()

# %%
plt.figure(figsize=(35,20))
sns.heatmap(df_corr,annot=True,annot_kws={'size':8})
plt.show()

# %% [markdown]
# # Observation:-
# Employee count,Over18 & Standard hours has no relationship between any other features.

# %%
data=data.drop(['EmployeeCount','Over18','StandardHours'],axis=1)

# %%
df_corr=data.corr().abs()

# %%
plt.figure(figsize=(35,24))
sns.heatmap(df_corr,annot=True,annot_kws={'size':8})
plt.show()

# %% [markdown]
# Joblabel & MonthlyIncome has high corelation

# %%
data=data.drop(['MonthlyIncome'],axis=1)

# %%
data.shape
# Out:
# (1470, 31)

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
x=data.drop('Attrition',axis=1)
y=data.Attrition

# %%
best_features=SelectKBest(score_func=f_classif,k=24)

# %%
fit=best_features.fit(x,y)

# %%
df_score=pd.DataFrame(fit.scores_)
df_columns=pd.DataFrame(x.columns)
feature_scores=pd.concat([df_columns,df_score],axis=1)
feature_scores.columns=['FeatureName','Score']
print(feature_scores.nlargest(24,'Score'))
# Out:
#                  FeatureName      Score
# 18                  OverTime  94.656457
# 23         TotalWorkingYears  44.252491
# 12                  JobLevel  43.215344
# 15             MaritalStatus  39.599763
# 27        YearsInCurrentRole  38.838303
# 0                        Age  38.175887
# 29      YearsWithCurrManager  36.712311
# 22          StockOptionLevel  28.140501
# 26            YearsAtCompany  27.001624
# 11            JobInvolvement  25.241985
# 14           JobSatisfaction  15.890004
# 8    EnvironmentSatisfaction  15.855209
# 4           DistanceFromHome   8.968277
# 13                   JobRole   6.649672
# 3                 Department   6.035877
# 25           WorkLifeBalance   6.026116
# 24     TrainingTimesLastYear   5.211646
# 2                  DailyRate   4.726640
# 21  RelationshipSatisfaction   3.095576
# 17        NumCompaniesWorked   2.782287
# 28   YearsSinceLastPromotion   1.602218
# 5                  Education   1.446308
# ...

# %%
new_x=data[['OverTime','TotalWorkingYears','JobLevel','MaritalStatus','YearsInCurrentRole','Age','YearsWithCurrManager','StockOptionLevel','YearsAtCompany','JobInvolvement','JobSatisfaction','EnvironmentSatisfaction','DistanceFromHome','JobRole','Department','WorkLifeBalance','TrainingTimesLastYear','DailyRate','RelationshipSatisfaction','NumCompaniesWorked','YearsSinceLastPromotion','Education','Gender','EducationField']]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_scalar=scaler.fit_transform(new_x)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scalar,y,test_size=0.25,random_state=240)

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn.predict(x_test)

# %%
cfm=confusion_matrix(y_test,y_pred)

# %%
cfm
# Out:
# array([[309,   2],
#        [ 48,   9]], dtype=int64)

# %%
print(classification_report(y_test,y_pred,digits=2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93       311
#            1       0.82      0.16      0.26        57
#
#     accuracy                           0.86       368
#    macro avg       0.84      0.58      0.59       368
# weighted avg       0.86      0.86      0.82       368
